# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# 0.5

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.items()

# %%
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]

# %%
data['e'] = 1.15
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.15
# dtype: float64

# %%
# срез через явный индекс
# значения последнего индекса включены
data['a':'c']
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
# срез через неявный целочисленный индекс
# значения последнего индекса не включены
data[0:2]
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
# маскирование
data[(data > 0.3) & (data < 0.8)]
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
# прихотливая индексация
data[['a', 'e']]
# Out:
# a    0.25
# e    1.15
# dtype: float64

# %%
data = pd.Series(['a', 'b', 'c'], index=[1, 3, 5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
data[1] # явный индекс
# Out:
# 'a'

# %%
data[1:3] # неявный
# Out:
# 3    b
# 5    c
# dtype: object

# %%
# явные индексы
data.loc[1]
# Out:
# 'a'

# %%
data.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
# неявные
data.iloc[1]
# Out:
# 'b'

# %%
data.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %% [markdown]
# # DataFrame

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Florida     170312  19552860
# Illinois    149995  12882135
# New York    141297  19651127
# Texas       695662  26448193

# %%
data['area']
# Out:
# California    423967
# Florida       170312
# Illinois      149995
# New York      141297
# Texas         695662
# Name: area, dtype: int64

# %%
data.area
# Out:
# California    423967
# Florida       170312
# Illinois      149995
# New York      141297
# Texas         695662
# Name: area, dtype: int64

# %%
data.area is data['area']
# Out:
# True

# %%
data['density'] = data['pop'] / data['area']
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763
# New York    141297  19651127  139.076746
# Texas       695662  26448193   38.018740

# %%
data.values
# Out:
# array([[  4.23967000e+05,   3.83325210e+07,   9.04139261e+01],
#        [  1.70312000e+05,   1.95528600e+07,   1.14806121e+02],
#        [  1.49995000e+05,   1.28821350e+07,   8.58837628e+01],
#        [  1.41297000e+05,   1.96511270e+07,   1.39076746e+02],
#        [  6.95662000e+05,   2.64481930e+07,   3.80187404e+01]])

# %%
data.T
# Out:
#            California       Florida      Illinois      New York         Texas
# area     4.239670e+05  1.703120e+05  1.499950e+05  1.412970e+05  6.956620e+05
# pop      3.833252e+07  1.955286e+07  1.288214e+07  1.965113e+07  2.644819e+07
# density  9.041393e+01  1.148061e+02  8.588376e+01  1.390767e+02  3.801874e+01

# %%
# доступ к строке
data.values[0]
# Out:
# array([  4.23967000e+05,   3.83325210e+07,   9.04139261e+01])

# %%
# доступ к столбцу
data['area']
# Out:
# California    423967
# Florida       170312
# Illinois      149995
# New York      141297
# Texas         695662
# Name: area, dtype: int64

# %%
# первые 3 строки и 2 столбца
data.iloc[:3, :2]
# Out:
#               area       pop
# California  423967  38332521
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data.loc[:'Illinois', :'pop']
# Out:
#               area       pop
# California  423967  38332521
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data.loc[data.density > 100, ['pop', 'density']]
# Out:
#                pop     density
# Florida   19552860  114.806121
# New York  19651127  139.076746

# %%
data.iloc[0, 2] = 90
data
# Out:
#               area       pop     density
# California  423967  38332521   90.000000
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763
# New York    141297  19651127  139.076746
# Texas       695662  26448193   38.018740

# %% [markdown]
# ### Индексация относится к столбцам, срезы относятся к строкам

# %%
data['Florida':'Illinois']
# Out:
#             area       pop     density
# Florida   170312  19552860  114.806121
# Illinois  149995  12882135   85.883763

# %%
data[1:3]
# Out:
#             area       pop     density
# Florida   170312  19552860  114.806121
# Illinois  149995  12882135   85.883763

# %%
data[data.density > 100]
# Out:
#             area       pop     density
# Florida   170312  19552860  114.806121
# New York  141297  19651127  139.076746
